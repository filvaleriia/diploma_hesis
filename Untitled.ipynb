# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import AllChem
from rdkit.Chem.Scaffolds.MurckoScaffold import GetScaffoldForMol
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles
from rdkit.Chem.Scaffolds.MurckoScaffold import MakeScaffoldGeneric
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_default = pd.read_csv("data/output_Molpher/output_data_after_Molpher/result_default.csv", header=None)

# %%
df_default
# Out:
#            0  1              2              3  \
# 0       1502  0  CHEMBL1389315  CHEMBL1356393
# 1       1502  0  CHEMBL1389315  CHEMBL1356393
# 2       1502  0  CHEMBL1389315  CHEMBL1356393
# 3       1502  0  CHEMBL1389315  CHEMBL1356393
# 4       1502  0  CHEMBL1389315  CHEMBL1356393
# ...      ... ..            ...            ...
# 292582  1940  4   CHEMBL295316  CHEMBL2334341
# 292583  1940  4   CHEMBL295316  CHEMBL2334341
# 292584  1940  4   CHEMBL295316  CHEMBL2334341
# 292585  1940  4   CHEMBL295316  CHEMBL2334341
# 292586  1940  4   CHEMBL295316  CHEMBL2334341
#
#                                                         4  \
# 0       O=S(=O)(Nc1c(c2nc3ccccc3nc2n1C4CCCCC4)S(=O)(=O...
# 1       O=S(=O)(Nc1c(c2nc3ccccc3nc2n1C4CCCCC4)S(=O)(=O...
# 2       O=S(=O)(Nc1c(c2nc3ccccc3nc2n1C4CCCCC4)S(=O)(=O...
# 3       O=S(=O)(Nc1c(c2nc3ccccc3nc2n1C4CCCCC4)S(=O)(=O...
# 4       O=S(=O)(Nc1c(c2nc3ccccc3nc2n1C4CCCCC4)S(=O)(=O...
# ...

# %%
df = df_default[6]

# %%
df.to_csv("example_for_generater_output.csv", index = False)

# %%
df_input = pd.read_csv("data/VDRML_chembl_inputs.csv")

# %%
df_input
# Out:
#                                                smiles      chembl_id
# 0   CCC(CC)(c1ccc(OC[C@H](O)C(C)(C)C)c(C)c1)c2ccc(...  CHEMBL1834893
# 1   CCOC(=O)\C=C\C1(CC1)[C@H](O)\C=C\[C@@H](C)[C@H...  CHEMBL2112315
# 2   CC\C(=C/C=C/C(O)(C(F)(F)F)C(F)(F)F)\c1cccc(CCc...  CHEMBL2171447
# 3   CC\C(=C/C=C/C(O)(C(F)(F)F)C(F)(F)F)\c1cccc(OCc...  CHEMBL2171448
# 4   CCCc1cc(ccc1c2cc(OCc3ccc(CO)c(CO)c3)ccc2CC)C(O...  CHEMBL2171449
# 5   CCCc1cc(ccc1c2cc(CCc3ccc(CO)c(CO)c3)ccc2C)C(O)...  CHEMBL2171450
# 6   CC[C@H](CCC(C)(C)O)[C@H](C)[C@H]1CCC2\C(=C\C=C...   CHEMBL222195
# 7   C[C@@H](CCCC(C)(C)O)C1CCC2\C(=C\C=C3C[C@@H](O)...   CHEMBL226380
# 8   CC[Si](CC)(c1ccc(OCC2CO2)c(C)c1)c3ccc(OCC(=O)C...  CHEMBL2334341
# 9   C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\C(=C\C=C/3\C...  CHEMBL2407821
# 10  C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\C(=C\C=C/3\C...  CHEMBL2407822
# 11  C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\C(=C\C=C/3\C...  CHEMBL2407823
# 12  C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\C(=C\C=C/3\C...  CHEMBL2407824
# ...

# %%
df_ = df_input["smiles"]

# %%
df_.to_csv("input_data.csv", index = False)

# %%
df_[1]
# Out:
# 'CCOC(=O)\\C=C\\C1(CC1)[C@H](O)\\C=C\\[C@@H](C)[C@H]2CC[C@H]3\\C(=C\\C=C/4\\C[C@@H](O)C[C@H](O)C4=C)\\CCC[C@]23C'

# %%
df_.head()
# Out:
# 0    CCC(CC)(c1ccc(OC[C@H](O)C(C)(C)C)c(C)c1)c2ccc(...
# 1    CCOC(=O)\C=C\C1(CC1)[C@H](O)\C=C\[C@@H](C)[C@H...
# 2    CC\C(=C/C=C/C(O)(C(F)(F)F)C(F)(F)F)\c1cccc(CCc...
# 3    CC\C(=C/C=C/C(O)(C(F)(F)F)C(F)(F)F)\c1cccc(OCc...
# 4    CCCc1cc(ccc1c2cc(OCc3ccc(CO)c(CO)c3)ccc2CC)C(O...
# Name: smiles, dtype: object

# %%
df = pd.read_csv("vdr.csv",sep=';')
df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0        CHEMBL1270149           NaN                   0            456.62
# 1        CHEMBL1270746           NaN                   0            560.78
# 2         CHEMBL403670           NaN                   0            458.64
# 3         CHEMBL403885           NaN                   0            458.64
# 4        CHEMBL1271360           NaN                   0            533.71
# ..                 ...           ...                 ...               ...
# 383          CHEMBL846    CALCITRIOL                   4            416.65
# 384      CHEMBL4449172           NaN                   0            458.64
# 385      CHEMBL4078953           NaN                   0            481.68
# 386      CHEMBL4063153           NaN                   0            486.70
# 387          CHEMBL846    CALCITRIOL                   4            416.65
#
#     #RO5 Violations AlogP       Compound Key  \
# ...

# %%
df = df.drop(['Compound Key'], axis=1)

# %%
#df = df[df['Standard Relation']=='\'=\'']

# %%
df = df[df['Standard Value'] > 500]
df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 20       CHEMBL3823776           NaN                   0            416.65
# 45        CHEMBL197946           NaN                   0            480.69
# 48       CHEMBL3823776           NaN                   0            416.65
# 54       CHEMBL3746116           NaN                   0            540.75
# 55       CHEMBL3746130           NaN                   0            484.64
# 56       CHEMBL3747395           NaN                   0            534.74
# 72       CHEMBL3633740           NaN                   0            588.83
# 81       CHEMBL3544529           NaN                   0            374.52
# 95       CHEMBL4078012           NaN                   0            467.65
# 120      CHEMBL3747284           NaN                   0            467.65
# 134      CHEMBL2437053           NaN                   0            484.64
# ...

# %%
df = df[df['Standard Value'] < 1500]

# %%
df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 20       CHEMBL3823776           NaN                   0            416.65
# 45        CHEMBL197946           NaN                   0            480.69
# 48       CHEMBL3823776           NaN                   0            416.65
# 54       CHEMBL3746116           NaN                   0            540.75
# 55       CHEMBL3746130           NaN                   0            484.64
# 56       CHEMBL3747395           NaN                   0            534.74
# 72       CHEMBL3633740           NaN                   0            588.83
# 81       CHEMBL3544529           NaN                   0            374.52
# 95       CHEMBL4078012           NaN                   0            467.65
# 120      CHEMBL3747284           NaN                   0            467.65
# 134      CHEMBL2437053           NaN                   0            484.64
# ...

# %%
x = 'Cl.O.O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1'
a = MurckoScaffoldSmiles(Chem.MolToSmiles(MakeScaffoldGeneric(Chem.MolFromSmiles(x))))
Chem.MolFromSmiles(a)

# %%
x = 'Cl.O=C1[C@H]2[C@@H]3CC[C@@H](C3)[C@H]2C(=O)N1C[C@@H]1CCCC[C@H]1CN1CCN(c2nsc3ccccc23)CC1'
a = MurckoScaffoldSmiles(Chem.MolToSmiles(MakeScaffoldGeneric(Chem.MolFromSmiles(x))))
Chem.MolFromSmiles(a)
