# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import AllChem
from rdkit.Chem.Scaffolds.MurckoScaffold import GetScaffoldForMol
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles
from rdkit.Chem.Scaffolds.MurckoScaffold import MakeScaffoldGeneric

#descripts
from rdkit.Chem import Lipinski
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors

from scipy.spatial import distance
from sklearn import manifold
from sklearn import decomposition
from sklearn import preprocessing

# plots
from matplotlib import pyplot
import seaborn

# %%
df = pd.read_csv('data_nuclear_target/ligand_Vitamin_receptor_EC50.csv', sep=';')
df = df.drop(['Molecule Name','Molecule Max Phase', '#RO5 Violations','Compound Key', 'Data Validity Comment', 'Target Name', 'Target Organism', 'Target Type', 'Document ChEMBL ID', 'Source ID',  'Assay Subcellular Fraction', 'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation', 'Target ChEMBL ID', 'Source Description', 'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties','Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID', 'BAO Label', 'Assay Organism','Assay Tissue ChEMBL ID','Assay Tissue Name', 'Assay Cell Type','Potential Duplicate', 'Uo Units', 'Ligand Efficiency BEI','Ligand Efficiency LE','Ligand Efficiency LLE','Ligand Efficiency SEI',], axis = 1)
df.head()
# Out:
#   Molecule ChEMBL ID  Molecular Weight AlogP  \
# 0      CHEMBL1270149            456.62  5.14
# 1      CHEMBL1270746            560.78  7.14
# 2       CHEMBL403670            458.64  4.93
# 3       CHEMBL403885            458.64  4.93
# 4      CHEMBL1271360            533.71  4.77
#
#                                               Smiles Standard Type  \
# 0  CCC(CC)(c1ccc(OCC(=O)C(C)(C)C)c(C)c1)c1ccc(OC[...          EC50
# 1  CCC(CC)(c1ccc(OCC(=O)C(C)(C)CCCc2ccccc2)c(C)c1...          EC50
# 2  CCC(CC)(c1ccc(OC[C@H](O)CO)c(C)c1)c1ccc(OC[C@H...          EC50
# 3  CCC(CC)(c1ccc(OC[C@@H](O)CO)c(C)c1)c1ccc(OC[C@...          EC50
# 4  CCC(CC)(c1ccc(OC[C@@H](O)CO)c(C)c1)c1ccc(O[C@@...          EC50
#
#   Standard Relation  Standard Value Standard Units  pChEMBL Value  \
# 0               NaN             NaN            NaN            NaN
# 1               '>'         30000.0             nM            NaN
# 2               '='            22.1             nM           7.66
# ...

# %%
Chem.MolFromSmiles(df['Smiles'][1])

# %%
Chem.MolFromSmiles(MurckoScaffoldSmiles(df['Smiles'][1]))

# %%
MakeScaffoldGeneric(Chem.MolFromSmiles(df['Smiles'][1]))

# %%
MakeScaffoldGeneric(Chem.MolFromSmiles(MurckoScaffoldSmiles(df['Smiles'][1])))

# %%
GetScaffoldForMol(Chem.MolFromSmiles(df['Smiles'][1]))
